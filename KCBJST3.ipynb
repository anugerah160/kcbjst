# %%
import random

def activation_function(net):
    return 1 if net >= 0.5 else 0

def main():
    # Input miu
    miu = float(input("Masukkan miu (Tingkat pembelajaran): "))

    # Inisialisasi bobot dan bias secara acak
    w = [random.random(), random.random()]
    b = random.random()

    # Input dan output logika OR secara default
    input_data = [(0, 0), (0, 1), (1, 0), (1, 1)]
    output_data = [0, 1, 1, 1]

    print("Data Logika OR:")
    for i in range(len(input_data)):
        print("x1={}, x2={} output={}".format(input_data[i][0], input_data[i][1], output_data[i]))

    # Pelatihan model
    for epoch in range(100):  # Jumlah iterasi

        total_error = 0

        for i in range(len(input_data)):
            # Perhitungan net input
            net = w[0] * input_data[i][0] + w[1] * input_data[i][1] + b

            # Perhitungan output dengan fungsi aktivasi
            output = activation_function(net)

            # Perhitungan error
            error = output_data[i] - output
            total_error += abs(error)

            # Update bobot dan bias
            w[0] += miu * error * input_data[i][0]
            w[1] += miu * error * input_data[i][1]
            b += miu * error

        # Cetak bobot, output, dan total error setiap epoch
        print("\nEpoch:", epoch + 1)
        print("Bobot (w1, w2):", w)
        print("Bias (b):", b)
        print("Detail Output:")
        for i in range(len(input_data)):
            net = w[0] * input_data[i][0] + w[1] * input_data[i][1] + b
            output = activation_function(net)
            print("x1={}, x2={} output={}".format(input_data[i][0], input_data[i][1], output))
        print("Total Error:", total_error)

        # Cek konvergensi
        if total_error == 0:
            break

if __name__ == "__main__":
    main()
# Out:
# Masukkan miu (Tingkat pembelajaran): 0.01
# Data Logika OR:
# x1=0, x2=0 output=0
# x1=0, x2=1 output=1
# x1=1, x2=0 output=1
# x1=1, x2=1 output=1
#
# Epoch: 1
# Bobot (w1, w2): [0.06699926680048994, 0.30016112564188735]
# Bias (b): 0.3417625893944868
# Detail Output:
# x1=0, x2=0 output=0
# x1=0, x2=1 output=1
# x1=1, x2=0 output=0
# x1=1, x2=1 output=1
# Total Error: 1
#
# Epoch: 2
# Bobot (w1, w2): [0.07699926680048993, 0.30016112564188735]
# Bias (b): 0.3517625893944868
# Detail Output:
# x1=0, x2=0 output=0
# x1=0, x2=1 output=1
# x1=1, x2=0 output=0
# x1=1, x2=1 output=1
# Total Error: 1
#
# Epoch: 3
# Bobot (w1, w2): [0.08699926680048993, 0.30016112564188735]
# Bias (b): 0.3617625893944868
# Detail Output:
# x1=0, x2=0 output=0
# x1=0, x2=1 output=1
# x1=1, x2=0 output=0
# x1=1, x2=1 output=1
# Total Error: 1
#
# Epoch: 4
# Bobot (w1, w2): [0.09699926680048993, 0.30016112564188735]
# Bias (b): 0.3717625893944868
# Detail Output:
# x1=0, x2=0 output=0
# x1=0, x2=1 output=1
# x1=1, x2=0 output=0
# x1=1, x2=1 output=1
# Total Error: 1
#
# Epoch: 5
# Bobot (w1, w2): [0.10699926680048992, 0.30016112564188735]
# Bias (b): 0.3817625893944868
# Detail Output:
# x1=0, x2=0 output=0
# x1=0, x2=1 output=1
# x1=1, x2=0 output=0
# x1=1, x2=1 output=1
# Total Error: 1
#
# Epoch: 6
# Bobot (w1, w2): [0.11699926680048992, 0.30016112564188735]
# Bias (b): 0.3917625893944868
# Detail Output:
# x1=0, x2=0 output=0
# x1=0, x2=1 output=1
# x1=1, x2=0 output=1
# x1=1, x2=1 output=1
# Total Error: 1
#
# Epoch: 7
# Bobot (w1, w2): [0.11699926680048992, 0.30016112564188735]
# Bias (b): 0.3917625893944868
# Detail Output:
# x1=0, x2=0 output=0
# x1=0, x2=1 output=1
# x1=1, x2=0 output=1
# x1=1, x2=1 output=1
# Total Error: 0
